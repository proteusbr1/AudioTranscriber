# %%
import os
import tempfile
from dotenv import load_dotenv
from pydub import AudioSegment
from openai import OpenAI

# Load environment variables from .env file
load_dotenv()

# Initialize the OpenAI client with your API key
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Import necessary exceptions from OpenAI
from openai import (
    APIError,
    OpenAIError,
    AuthenticationError,
    RateLimitError,
    APIConnectionError,
)


def extract_audio(video_file_path, audio_format='mp3'):
    """
    Extracts audio from a video file and saves it as an audio file.

    :param video_file_path: Path to the video file.
    :param audio_format: Desired audio format (default: 'mp3').
    :return: Path to the extracted audio file.
    """
    try:
        print(f"Extracting audio from video file: {video_file_path}")
        # Load the video file
        audio = AudioSegment.from_file(video_file_path)

        # Create a temporary file to save the extracted audio
        temp_audio_file = tempfile.NamedTemporaryFile(delete=False, suffix=f".{audio_format}")
        audio.export(temp_audio_file.name, format=audio_format)
        print(f"Audio extracted and saved to temporary file: {temp_audio_file.name}")
        return temp_audio_file.name
    except Exception as e:
        print(f"Failed to extract audio from video file: {e}")
        return None


def split_audio(file_path, max_size_mb=25, safety_margin=5000):
    """
    Splits an audio file into smaller segments that are below the specified maximum size.

    :param file_path: Path to the original audio file.
    :param max_size_mb: Maximum size of each segment in megabytes.
    :param safety_margin: Number of bytes to subtract as safety margin.
    :return: List of paths to the split audio files.
    """
    try:
        # Load the audio file
        audio = AudioSegment.from_file(file_path)
        max_size_bytes = max_size_mb * 1024 * 1024 - safety_margin

        # Set the bitrate for exporting in bytes per second
        export_bitrate_kbps = 128  # kbps
        export_bitrate_bps = (export_bitrate_kbps * 1000) / 8  # Convert to bytes per second

        # Calculate the duration for each segment in milliseconds
        segment_duration_sec = max_size_bytes / export_bitrate_bps
        segment_duration_ms = segment_duration_sec * 1000

        print(f"Export bitrate: {export_bitrate_kbps} kbps")
        print(f"Estimated duration per segment: {segment_duration_sec:.2f} seconds")

        segments = []
        # Split the audio into segments
        for start_ms in range(0, len(audio), int(segment_duration_ms)):
            end_ms = start_ms + int(segment_duration_ms)
            segment = audio[start_ms:end_ms]
            segment_file = f"{os.path.splitext(file_path)[0]}_part{len(segments)+1}.mp3"
            segment.export(segment_file, format="mp3", bitrate=f"{export_bitrate_kbps}k")
            segments.append(segment_file)
            actual_file_size = os.path.getsize(segment_file)
            print(f"Exported: {segment_file} ({start_ms/1000:.2f} - {min(end_ms/1000, len(audio)/1000):.2f} seconds), size: {actual_file_size} bytes")
        return segments
    except Exception as e:
        print(f"Failed to split audio file: {e}")
        return []


def transcribe_audio(file_path, language=None, response_format="json"):
    """
    Transcribes an audio file using the OpenAI Whisper API.

    :param file_path: Path to the audio file.
    :param language: (Optional) Language code of the audio (e.g., "en" for English).
    :param response_format: Response format ("json", "text", "verbose_json", etc.).
    :return: Transcription text or None in case of error.
    """
    try:
        with open(file_path, "rb") as audio_file:
            print(f"Sending {file_path} to OpenAI Whisper API for transcription...")
            transcription = client.audio.transcriptions.create(
                model="whisper-1",
                file=audio_file,
                language=language,
                response_format=response_format
            )
            print(f"Transcription successful for file: {file_path}")
            return transcription.text
    except AuthenticationError as e:
        print("Authentication error with OpenAI API:", e)
    except RateLimitError as e:
        print("Rate limit exceeded. Please try again later:", e)
    except APIConnectionError as e:
        print("Connection issue with OpenAI API:", e)
    except APIError as e:
        print("General API error from OpenAI:", e)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An unexpected error occurred during transcription: {e}")
    return None


def main(input_file_path, language="en"):
    """
    Main function to extract audio from video (if necessary), split it if too large, and transcribe.

    :param input_file_path: Path to the original audio or video file.
    :param language: Language code of the audio (default: "en" for English).
    """
    # Check if the file exists
    if not os.path.exists(input_file_path):
        print(f"File not found: {input_file_path}")
        return

    # Determine if the input file is a video based on its extension
    video_extensions = {'.mp4', '.mov', '.avi', '.mkv', '.flv', '.wmv'}
    file_ext = os.path.splitext(input_file_path)[1].lower()

    audio_file_path = input_file_path  # Default to input file

    # If the file is a video, extract the audio
    if file_ext in video_extensions:
        audio_file_path = extract_audio(input_file_path, audio_format='mp3')
        if not audio_file_path:
            print("Audio extraction failed. Cannot proceed with transcription.")
            return

    try:
        # Check the file size
        file_size = os.path.getsize(audio_file_path)
        max_size_mb = 25
        max_size_bytes = max_size_mb * 1024 * 1024

        if file_size <= max_size_bytes:
            print("The file is within the size limit. Proceeding with transcription.")
            transcription = transcribe_audio(audio_file_path, language=language)
            if transcription:
                print("\n--- Audio Transcription ---")
                print(transcription)
            else:
                print("Failed to transcribe the audio.")
        else:
            print(f"The file exceeds the {max_size_mb} MB limit (current size: {file_size / (1024 * 1024):.2f} MB).")
            print("Splitting the file into smaller parts...")

            # Split the audio into smaller parts
            segments = split_audio(audio_file_path, max_size_mb=max_size_mb)
            all_transcriptions = []

            # Transcribe each segment
            for segment in segments:
                print(f"\nTranscribing: {segment}")
                transcription = transcribe_audio(segment, language=language)
                if transcription:
                    all_transcriptions.append(transcription)
                    print(f"Transcription of {segment} completed.")
                else:
                    print(f"Failed to transcribe {segment}.")

            # Combine all transcriptions
            combined_transcription = "\n".join(all_transcriptions)
            print("\n--- Complete Audio Transcription ---")
            print(combined_transcription)
    finally:
        # Clean up temporary audio file if it was extracted from a video
        if file_ext in video_extensions and audio_file_path and os.path.exists(audio_file_path):
            try:
                os.remove(audio_file_path)
                print(f"Temporary audio file deleted: {audio_file_path}")
            except Exception as e:
                print(f"Failed to delete temporary audio file: {e}")


if __name__ == "__main__":
    # Replace with the correct path to your audio or video file
    input_file_path = "audio.mp4"  # Example: "C:/Users/YourUser/Videos/video.mp4"

    # Call the main function
    main(input_file_path, language="en")  # Set the language as needed
# Out:
# Extracting audio from video file: audio.mp4
# Audio extracted and saved to temporary file: /tmp/tmp1mrjvp_j.mp3
# The file exceeds the 25 MB limit (current size: 102.23 MB).
# Splitting the file into smaller parts...
# Export bitrate: 128 kbps
# Estimated duration per segment: 1638.40 seconds
# Exported: /tmp/tmp1mrjvp_j_part1.mp3 (0.00 - 1638.40 seconds)
# Exported: /tmp/tmp1mrjvp_j_part2.mp3 (1638.40 - 3276.80 seconds)
# Exported: /tmp/tmp1mrjvp_j_part3.mp3 (3276.80 - 4915.20 seconds)
# Exported: /tmp/tmp1mrjvp_j_part4.mp3 (4915.20 - 6553.60 seconds)
# Exported: /tmp/tmp1mrjvp_j_part5.mp3 (6553.60 - 8192.00 seconds)
# Exported: /tmp/tmp1mrjvp_j_part6.mp3 (8192.00 - 9830.40 seconds)
# Exported: /tmp/tmp1mrjvp_j_part7.mp3 (9830.40 - 11468.80 seconds)
# Exported: /tmp/tmp1mrjvp_j_part8.mp3 (11468.80 - 13107.20 seconds)
# Exported: /tmp/tmp1mrjvp_j_part9.mp3 (13107.20 - 14745.60 seconds)
# Exported: /tmp/tmp1mrjvp_j_part10.mp3 (14745.60 - 16384.00 seconds)
# Exported: /tmp/tmp1mrjvp_j_part11.mp3 (16384.00 - 17866.50 seconds)
#
# Transcribing: /tmp/tmp1mrjvp_j_part1.mp3
# Sending /tmp/tmp1mrjvp_j_part1.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part1.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part2.mp3
# Sending /tmp/tmp1mrjvp_j_part2.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part2.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part3.mp3
# Sending /tmp/tmp1mrjvp_j_part3.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part3.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part4.mp3
# Sending /tmp/tmp1mrjvp_j_part4.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part4.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part5.mp3
# Sending /tmp/tmp1mrjvp_j_part5.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part5.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part6.mp3
# Sending /tmp/tmp1mrjvp_j_part6.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part6.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part7.mp3
# Sending /tmp/tmp1mrjvp_j_part7.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part7.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part8.mp3
# Sending /tmp/tmp1mrjvp_j_part8.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part8.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part9.mp3
# Sending /tmp/tmp1mrjvp_j_part9.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216701 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part9.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part10.mp3
# Sending /tmp/tmp1mrjvp_j_part10.mp3 to OpenAI Whisper API for transcription...
# General API error from OpenAI: Error code: 413 - {'error': {'message': '413: Maximum content size limit (26214400) exceeded (26216702 bytes read)', 'type': 'server_error', 'param': None, 'code': None}}
# Failed to transcribe /tmp/tmp1mrjvp_j_part10.mp3.
#
# Transcribing: /tmp/tmp1mrjvp_j_part11.mp3
# Sending /tmp/tmp1mrjvp_j_part11.mp3 to OpenAI Whisper API for transcription...
# Transcription successful for file: /tmp/tmp1mrjvp_j_part11.mp3
# Transcription of /tmp/tmp1mrjvp_j_part11.mp3 completed.
#
# --- Complete Audio Transcription ---
# There are people who don't know who the mayor is, even today, in this condominium. I think this is regrettable. I also think it's regrettable that a condominium has 300 residences, and there are 40 people participating. It's regrettable, because tomorrow there won't be anyone who will ask why it was decided like this. So that's it, and let's touch the boat, please, because it's 11 o'clock, people. Does anyone else want to speak? Mr. Mayor, I'm sorry, Larissa had to leave, and only Angela, another online resident supporter. There are more people in the line, can I speak? Please. I think it's me. It's me, Q4. Now, H11. H11, what are you saying? I already said it, H11 already said it, you can take it off. So now, E21 too. E21, I said it. E16. Q04. It's me. When I did the registration, I had a doubt, but I just wanted to ratify this understanding. From what I understood from Cesar's presentation, and after reading Carol's, we have two positions, or two lines of action, in relation to energy. Cesar understands that the best way, perhaps, is the part of the negotiation, together with Neoenergia, trying to save money, or wanting to negotiate, or extend the term. And from what I saw from the study, from the reading, which I had not understood in this way, from the presentation in relation to the fiscal council, which intends to pay R$ 9,000 to update the plan for 2021, to present this plan, and try to make a negotiation on paper, in relation to this future proclamation or discussion of the rights of A or B. Is that exactly it? No, they are different situations. The issue of charging for public electricity, which was addressed by Cesar, is not addressed in the Council's report. This proposal of the project is for us to modernize our network of electricity distribution, to minimize or solve the issues of energy failure, of instability, which happens especially from Group A to Group J. I had understood that Cesar, after you did the reading, said that there was a small difference in relation to the appearance, and that's why I was induced to this interpretation. But I think it's interesting to make it clear, if it's not just me who didn't understand, and maybe others, exactly this distinction. One thing, then, is that Cesar wants to see the issue of this passive in relation to the charging of public energy, of the discussion of the charging of energy for public posts. This is an issue. From what I understood, he has already satisfied, maybe there is no other solution in relation to this. The other, in relation to the Council, is what to do with this problem, as you said, of the Groups A or K in relation to the instability of energy. So, we are here kind of discussing, back and forth, but I think that the two actions can continue. Cesar, make your negotiation and try to present, as soon as he has an answer, through a statement, so that he can be aware of the success he can have in this negotiation of his, and in the same way, in relation to the Council, I think that these R$ 9,000 have already been approved, I think it was the decision of the previous Council, was it? This was an internal decision of the Council with the administration, and then the administration went back, because, according to the verbalization of TerraCap, this would not be feasible. And then, Cesar's manifestation of disagreement is that he believes that we should not initiate this negotiation formally. Do you understand? I understand. In his opinion, we should not update the project, we should not submit the energy ring, we should not submit TerraCap. And what would be this other solution? And what would be this other solution, and not doing, theoretically, what Figurino says? And not doing anything. Wait for the end of the revalidation. Ah, ok. Not doing anything is for a reason of waiting for the end of the regularization to discuss this issue at the time of the regularization, is that it? It is after the regularization. Cesar understands that this has to be postpo ...
# Temporary audio file deleted: /tmp/tmp1mrjvp_j.mp3
